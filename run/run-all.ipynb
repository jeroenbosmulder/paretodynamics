# %%
# %run ../graphics/01-remaining-solutions-plot.ipynb
# %run ../graphics/02-small-gass-plot.ipynb
# %run ../graphics/03-small-gas-cooling-down.ipynb
# %run ../graphics/04-small-gas-cooling-down-to-zero.ipynb
# %run ../graphics/05-critical-temperature.ipynb
# %run ../graphics/05-cooling-factors.ipynb
# %run ../graphics/06-critical-cooling-factor.ipynb
# Out:
# 999 1.0
